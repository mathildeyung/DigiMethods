# %% [markdown]
# # Data formats and open data
# **Exercises for week 5B** in Digital Methods, University of Copenhagen

# %%
pip install BeautifulSoup4
# Out:
# Requirement already satisfied: BeautifulSoup4 in /Users/mathildemeiling/opt/anaconda3/lib/python3.7/site-packages (4.8.0)
# Requirement already satisfied: soupsieve>=1.2 in /Users/mathildemeiling/opt/anaconda3/lib/python3.7/site-packages (from BeautifulSoup4) (1.9.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup

# %% [markdown]
# ## 1. HTML

# %% [markdown]
# HTML is the markup language used by web pages. It's ubiquitous on the web; even when editing this notebook you are interacting with HTML (right click and hit "View Page Source" if you need proof). Here follows some exercises to get you comfortable with navigating HTML on web pages.

# %% [markdown]
# > **Ex. 1**: Right click inside the cell below and hit "Inspect". This should launch the "Inspector" tool in your browser, showing you where the element that renders the cell sits inside the DOM.
# 1. How deeply is it nested? Are there any sibling elements?
# 2. What happens when you update it? Change the text and see for yourself.
# >
# > *Hint: Most modern browsers (e.g. Firefox, Chrome, Brave) will let you hover elements in the DOM to show where they display on the web page.*

# %% [markdown]
# *HTML is a beautiful soup of hypertext*

# %% [markdown]
# > **Ex. 2**: In the HTML code below:
# 1. What is typically the use of the `<p>`, `<h1>` and `<h2>` tags? Look them up, what are they for?
# 2. What are the attributes of the `div` element?
# 3. Create a text file that ends with ".html" and open it in a browser.

# %%
#The <p> is used for paragraphs/text, <h1> is used for headlines, and <h2> for subheaders 
#The div element is a container - usually everything is nested within divs 
#Look at HTML example (saved in digimethods)

# %% [markdown]
#     <html>
#     <body>
#
#     <div width=200 height=100 id="main">
#         <h1>This is the main title of the webpage</h1>
#         <h2>This is a sub-heading</h2>
#         <p>This is a paragraph of text.</p>
#     </div>
#
#     <h2>This is another sub-heading</h2>
#     <p>This is a paragraph of text with some words in bold.</p>
#     <img src="https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Fmedia.giphy.com%2Fmedia%2FkFgzrTt798d2w%2Fgiphy.gif&f=1&nofb=1" width="493" height="340">
#     <p>And that just above is an image.</p>
#
#     </body>
#     </html>

# %% [markdown]
# > **Ex. 3**: Using the `requests` module, download [this web page](https://www.boliga.dk/resultat?propertyType=3&zipCodes=2200&page=1). Print the first 100 lines of the html string. How many lines are there in total?
# >
# > *Hint: use the `requests.get` method. To figure out how it works, execute `?requests.get` (after importing `requests`), this displays the module documentation.*

# %%
import requests

# %%
boliga_url = "https://www.boliga.dk/resultat?propertyType=3&zipCodes=2200&page=1"

boliga_response = requests.get(boliga_url)

boliga_soup = BeautifulSoup(boliga_response.text, "html.parser")

# %%
boliga_text = boliga_soup.find_all("p") #bs4 objects come out as lists 

len(boliga_text)
# Out:
# 368

# %%
boliga_text[0:100]
# Out:
# [<p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Ejerlejlighed <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Nørrebro - Holm &amp; Hauberg <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Ejerlejlighed <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Pris er faldet <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Boligstørrelse <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Nørrebro - Holm &amp; Hauberg <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Bagsværd - Holm &amp; Hauberg <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Ejerlejlighed <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Pris er faldet <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Boligstørrelse <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Bagsværd - Holm &amp; Hauberg <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Ejerlejlighed <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Ejerlejlighed <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Pris er faldet <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Oprettet 1. mar. 2020 <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Boligstørrelse <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Byggeår <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Grundstørrelse <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Ejerudgift - de samlede månedlige udgifter til boligen uden lån <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Ejerlejlighed <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Pris er faldet <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Oprettet 25. feb. 2020 <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Boligstørrelse <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Byggeår <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Grundstørrelse <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Ejerudgift - de samlede månedlige udgifter til boligen uden lån <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Ejerlejlighed <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Pris er faldet <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Oprettet 16. okt. 2019 <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Boligstørrelse <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Byggeår <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Grundstørrelse <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Ejerudgift - de samlede månedlige udgifter til boligen uden lån <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Ejerlejlighed <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Pris er faldet <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Oprettet 27. feb. 2020 <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Boligstørrelse <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Byggeår <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Grundstørrelse <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Ejerudgift - de samlede månedlige udgifter til boligen uden lån <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Ejerlejlighed <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Pris er faldet <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Oprettet 29. feb. 2020 <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Boligstørrelse <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Byggeår <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Grundstørrelse <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Ejerudgift - de samlede månedlige udgifter til boligen uden lån <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Ejerlejlighed <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Pris er faldet <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Oprettet 5. mar. 2020 <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Boligstørrelse <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Byggeår <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Grundstørrelse <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Ejerudgift - de samlede månedlige udgifter til boligen uden lån <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Ejerlejlighed <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Pris er faldet <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Oprettet 13. aug. 2019 <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Boligstørrelse <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Byggeår <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Grundstørrelse <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Ejerudgift - de samlede månedlige udgifter til boligen uden lån <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Ejerlejlighed <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Pris er faldet <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Oprettet 9. jan. 2020 <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Boligstørrelse <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Byggeår <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Grundstørrelse <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Ejerudgift - de samlede månedlige udgifter til boligen uden lån <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Ejerlejlighed <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Pris er faldet <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Oprettet 24. jan. 2020 <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Boligstørrelse <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Byggeår <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Grundstørrelse <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Ejerudgift - de samlede månedlige udgifter til boligen uden lån <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Ejerlejlighed <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Pris er faldet <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Oprettet 26. sep. 2019 <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Boligstørrelse <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Byggeår <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Grundstørrelse <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Ejerudgift - de samlede månedlige udgifter til boligen uden lån <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Ejerlejlighed <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Pris er faldet <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Oprettet 5. feb. 2020 <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Boligstørrelse <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Byggeår <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Grundstørrelse <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Ejerudgift - de samlede månedlige udgifter til boligen uden lån <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Ejerlejlighed <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Pris er faldet <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Oprettet 24. sep. 2019 <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Boligstørrelse <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Byggeår <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Grundstørrelse <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Ejerudgift - de samlede månedlige udgifter til boligen uden lån <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Nørrebro - Holm &amp; Hauberg <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Ejerlejlighed <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Pris er faldet <!-- --><!-- --></p>,
#  <p _ngcontent-sc39="" class="app-tooltip"><!-- --><!-- --> Oprettet 16. nov. 2019 <!-- --><!-- --></p>]

# %%
print(boliga_soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <!-- Google Tag Manager -->
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-PWD5VZT');
#   </script>
#   <!-- End Google Tag Manager -->
#   <meta charset="utf-8"/>
#   <meta content="2200 København N &amp; Ejerlejlighed. Udforsk boligerne og få alle oplysninger om boligen, inden du køber. Se resultaterne på en liste her." name="description"/>
#   <meta content="" name="keywords"/>
#   <title>
#    2200 København N &amp; Ejerlejlighed - Boliga.dk
#   </title>
#   <base href="/"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=0" name="viewport"/>
#   <link href="favicon.ico" rel="icon" type="image/x-icon"/>
#   <link href="https://fonts.googleapis.com/css?family=Montserrat:400,500,600,700" rel="stylesheet"/>
#   <script src="https://connect.facebook.net/en_US/sdk.js" type="text/javascript">
#   </script>
#   <script data-culture="DA" id="CookieConsent" src="./assets/images/cookieConsent.js">
#   </script>
#   <!--<script id="CookieConsent" data-culture="DA" src="https://policy.app.cookieinformation.com/uc.js"></script>-->
#   <link href="styles.854ad6897c71e66e620d.css" rel="stylesheet"/>
#   <style ng-transition="boliga-app">
#   </style>
#   <style ng-transition="boliga-app">
#    .app-header.header-shadow {
#   box-shadow: 0 0 30px 0 rgba(0, 0, 0, 0.2);
# }
#
# .app-header.theme-light .header-line {
#   background-color: #fff;
# }
#
# .app-header.theme-light .header-line .burger {
#   background: #f7f7f7;
# }
#
# .app-header.theme-light .header-line .burger svg {
#   fill: #6091C0 !important;
# }
#
# .app-header.theme-light .header-line .logo svg {
#   fill: #6091C0;
# }
#
# .app-header.theme-light .header-line .app-search-edit-panel {
#   padding: 0 !important;
#   margin: 0 !important;
#   border: 0 !important;
# }
#
# .app-header.theme-light .header-line .app-search-edit-panel .app-search-on-map-nav {
#   display: none !important;
# }
#
# .app-header.transparent .header-line {
#   background: rgba(0, 0, 0, 0.7);
# }
#
# .app-header.transparent .header-line .burger {
#   background: #000;
# }
#
# .app-header {
#   height: 65px;
# }
#
# @media (max-width: 767.98px) {
#   .app-header {
#     height: 54px;
#   }
# }
#
# .app-header.double-height {
#   height: 130px;
# }
#
# .app-header .header-line {
#   background-color: #6091C0;
#   height: 65px;
#   top: 0;
#   left: 0;
#   z-index: 1004;
# }
#
# @media (max-width: 767.98px) {
#   .app-header .header-line {
#     height: 54px;
#   }
# }
#
# .app-header.transparent {
#   height: 0;
# }
#
# .app-header.theme-light .second-line {
#   top: 65px;
# }
#
# .app-header .logo svg {
#   fill: #fff;
#   width: 92px;
#   height: 28px;
# }
#
# @media (max-width: 767.98px) {
#   .app-header .logo a {
#     width: 54px;
#   }
#   .app-header .logo a svg {
#     width: 21px;
#     height: 17px;
#   }
# }
#
# .app-header app-header-search {
#   margin-right: 20px;
# }
#
# .app-header .filter-buttons-cont {
#   padding-left: 104px;
# }
#
# .app-header-advanced-search {
#   position: absolute;
#   top: 65px;
#   width: 100%;
#   min-height: calc(100% - 65px);
#   z-index: 9;
#   background: linear-gradient(180deg, #f7f7f7 0%, #fff 400px);
#   padding: 25px 0 40px 0;
# }
#
# .app-header-advanced-search.header-opened {
#   top: 130px;
#   min-height: calc(100% - 130px);
# }
#   </style>
#   <style ng-transition="boliga-app">
#    .footer[_ngcontent-sc3] {
#   width: 100%;
#   background-color: #223e59;
#   color: white;
# }
#
# .main[_ngcontent-sc3] {
#   display: -webkit-box;
#   display: flex;
#   flex-wrap: wrap;
#   width: 100%;
#   padding: 36px 0 33px 0;
# }
#
# .copyright[_ngcontent-sc3] {
#   padding: 10px 0;
#   background-color: rgba(0, 0, 0, 0.1);
# }
#
# .copyright[_ngcontent-sc3]   span[_ngcontent-sc3] {
#   opacity: 0.5;
#   font-size: 14px;
# }
#
# @media (max-width: 767.98px) {
#   .main[_ngcontent-sc3] {
#     padding: 40px 0 20px 0;
#   }
# }
#   </style>
#   <style ng-transition="boliga-app">
#    .sidebar[_ngcontent-sc4] {
#   position: fixed;
#   top: 0;
#   left: 0;
#   width: 100%;
#   max-width: 375px;
#   height: 100%;
#   background: #f5f5f5;
#   overflow: hidden;
#   z-index: 1006;
#   -webkit-transform: translateX(-100%);
#           transform: translateX(-100%);
#   -webkit-transition: -webkit-transform 0.4s;
#   transition: -webkit-transform 0.4s;
#   transition: transform 0.4s;
#   transition: transform 0.4s, -webkit-transform 0.4s;
# }
# .sidebar.open[_ngcontent-sc4] {
#   -webkit-transform: translateX(0);
#           transform: translateX(0);
# }
# .sidebar[_ngcontent-sc4]   .sidebar-menu[_ngcontent-sc4] {
#   position: absolute;
#   top: 0;
#   right: 0;
#   overflow-y: auto;
#   width: 100%;
#   height: 100%;
#   background: #F5F5F5;
# }
# @media (max-width: 767.98px) {
#   .sidebar[_ngcontent-sc4]   .sidebar-menu[_ngcontent-sc4] {
#     -webkit-overflow-scrolling: touch;
#   }
# }
# .sidebar[_ngcontent-sc4]   .sidebar-menu[_ngcontent-sc4]   .close-button[_ngcontent-sc4] {
#   position: relative;
#   background: transparent;
#   border: 0;
#   font: 0/0 a;
#   margin: 12px 0 10px 17px;
#   padding: 5px;
#   cursor: pointer;
#   -webkit-transition: background 0.15s;
#   transition: background 0.15s;
# }
# .sidebar[_ngcontent-sc4]   .sidebar-menu[_ngcontent-sc4]   .close-button[_ngcontent-sc4]:hover {
#   background: rgba(0, 0, 0, 0.1);
# }
# .sidebar[_ngcontent-sc4]   .sidebar-menu[_ngcontent-sc4]   .close-button[_ngcontent-sc4]   svg[_ngcontent-sc4] {
#   width: 20px;
#   height: 20px;
#   fill: #000;
# }
# .sidebar[_ngcontent-sc4]   .sidebar-menu[_ngcontent-sc4]   .logo[_ngcontent-sc4] {
#   position: relative;
#   top: 7px;
#   left: 15px;
#   display: inline-block;
# }
# .sidebar[_ngcontent-sc4]   .sidebar-menu[_ngcontent-sc4]   .logo[_ngcontent-sc4]   a[_ngcontent-sc4]   svg[_ngcontent-sc4] {
#   width: 92px;
#   height: 28px;
#   fill: #000;
# }
# .sidebar[_ngcontent-sc4]   .sidebar-menu[_ngcontent-sc4]   .logout-button[_ngcontent-sc4] {
#   position: absolute;
#   top: 17px;
#   right: 15px;
#   font-weight: 600;
#   color: #5A626B;
#   cursor: pointer;
# }
# .sidebar[_ngcontent-sc4]   .sidebar-menu[_ngcontent-sc4]   .logout-button[_ngcontent-sc4]   a[_ngcontent-sc4]   svg[_ngcontent-sc4] {
#   width: 21px;
#   height: 22px;
#   margin-right: 5px;
#   margin-bottom: 2px;
#   fill: currentColor;
#   stroke: currentColor;
# }
# .sidebar[_ngcontent-sc4]   .sidebar-menu[_ngcontent-sc4]   .extra-menu[_ngcontent-sc4] {
#   padding-top: 15px;
# }
# .sidebar[_ngcontent-sc4]   .sidebar-menu[_ngcontent-sc4]   .extra-menu[_ngcontent-sc4]    > *[_ngcontent-sc4] {
#   border-bottom: 1px solid rgba(255, 255, 255, 0.2);
# }
# .sidebar[_ngcontent-sc4]   .sidebar-menu[_ngcontent-sc4]   .extra-menu[_ngcontent-sc4]    > *[_ngcontent-sc4]:last-child {
#   border-bottom: 0;
# }
# .sidebar[_ngcontent-sc4]   .sidebar-menu[_ngcontent-sc4]   .extra-menu[_ngcontent-sc4]   .profile-button[_ngcontent-sc4] {
#   width: 100%;
#   padding: 12px 14px;
#   background-color: #6091C0;
#   display: -webkit-box;
#   display: flex;
#   color: #fff;
#   font-weight: bold;
#   text-decoration: none;
#   cursor: pointer;
# }
# .sidebar[_ngcontent-sc4]   .sidebar-menu[_ngcontent-sc4]   .extra-menu[_ngcontent-sc4]   .profile-button[_ngcontent-sc4]   .button-text[_ngcontent-sc4] {
#   -webkit-box-flex: 1;
#           flex-grow: 1;
#   text-align: left;
# }
# .sidebar[_ngcontent-sc4]   .sidebar-menu[_ngcontent-sc4]   .extra-menu[_ngcontent-sc4]   .profile-button[_ngcontent-sc4]   .chevron[_ngcontent-sc4] {
#   height: 13px;
#   width: 13px;
#   fill: #fff;
# }
# .sidebar[_ngcontent-sc4]   .sidebar-menu[_ngcontent-sc4]   .extra-menu[_ngcontent-sc4]   .profile-button[_ngcontent-sc4]:hover {
#   background-color: #3566ac;
# }
# .sidebar-menu-overlay[_ngcontent-sc4] {
#   position: fixed;
#   top: 0;
#   left: 0;
#   width: 100%;
#   height: 100%;
#   background: rgba(0, 0, 0, 0.8);
#   opacity: 0;
#   z-index: 1005;
#   -webkit-transition: opacity 0.3s;
#   transition: opacity 0.3s;
#   pointer-events: none;
# }
# .sidebar-menu-overlay.open[_ngcontent-sc4] {
#   opacity: 100;
#   pointer-events: all;
# }
#   </style>
#   <style ng-transition="boliga-app">
#    .burger[_ngcontent-sc5] {
#   width: 63px;
#   height: 65px;
#   margin: 0 20px;
#   background: rgba(0, 0, 0, 0.3);
#   border: 0;
#   cursor: pointer;
# }
# .burger[_ngcontent-sc5]   svg[_ngcontent-sc5] {
#   width: 21px;
#   height: 20px;
#   fill: #fff;
# }
# @media (max-width: 767.98px) {
#   .burger[_ngcontent-sc5] {
#     width: 53px;
#     height: 54px;
#     margin-left: 0;
#     margin-right: 0;
#   }
# }
#   </style>
#   <style ng-transition="boliga-app">
#    .h-6[_ngcontent-sc6] {
#   line-height: 1rem;
# }
#
# @media (min-width: 576px) {
#   .menu-link[_ngcontent-sc6] {
#     font-size: 13px;
#   }
# }
#
# .user-menu-box[_ngcontent-sc6] {
#   width: 180px;
# }
#
# .badge[_ngcontent-sc6] {
#   font-size: 65%;
#   position: absolute;
#   right: 0;
#   top: -1rem;
# }
#   </style>
#   <style ng-transition="boliga-app">
#    .sidebar-menu-block[_ngcontent-sc12] {
#   margin-top: 16px;
#   box-shadow: 0px 7px 10px rgba(0, 0, 0, 0.05);
# }
# .sidebar-menu-block[_ngcontent-sc12]   .title[_ngcontent-sc12] {
#   color: #5a626b;
#   font-size: 12px;
#   font-weight: 600;
#   text-transform: uppercase;
#   padding-left: 19px;
#   margin-bottom: 6px;
# }
# .sidebar-menu-block[_ngcontent-sc12]   .sidebar-menu-item[_ngcontent-sc12] {
#   display: -webkit-box;
#   display: flex;
#   -webkit-box-align: center;
#           align-items: center;
#   height: 50px;
#   border-bottom: 1px solid rgba(0, 0, 0, 0.12);
#   background: #fff;
#   color: #000;
#   font-size: 16px;
#   font-weight: 600;
#   text-decoration: none;
#   -webkit-transition: background 0.15s;
#   transition: background 0.15s;
# }
# .sidebar-menu-block[_ngcontent-sc12]   .sidebar-menu-item[_ngcontent-sc12]:hover {
#   background: #eff8ff;
# }
# .sidebar-menu-block[_ngcontent-sc12]   .sidebar-menu-item[_ngcontent-sc12]:first-of-type {
#   border-top: 1px solid rgba(0, 0, 0, 0.12);
# }
# .sidebar-menu-block[_ngcontent-sc12]   .sidebar-menu-item[_ngcontent-sc12]   .icon[_ngcontent-sc12] {
#   flex-shrink: 0;
#   position: relative;
#   width: 64px;
# }
# .sidebar-menu-block[_ngcontent-sc12]   .sidebar-menu-item[_ngcontent-sc12]   .icon[_ngcontent-sc12]   svg[_ngcontent-sc12] {
#   position: absolute;
#   top: 0;
#   left: 0;
#   right: 0;
#   bottom: 0;
#   margin: auto;
#   width: 25px;
#   height: 25px;
#   fill: #6091C0;
#   stroke: #6091C0;
#   color: #6091C0;
# }
# .sidebar-menu-block[_ngcontent-sc12]   .sidebar-menu-item[_ngcontent-sc12]   .label[_ngcontent-sc12] {
#   -webkit-box-flex: 1;
#           flex-grow: 1;
# }
# .sidebar-menu-block[_ngcontent-sc12]   .sidebar-menu-item[_ngcontent-sc12]   app-badge[_ngcontent-sc12] {
#   width: 50px;
#   flex-shrink: 0;
# }
# .sidebar-menu-block[_ngcontent-sc12]   .sidebar-menu-item[_ngcontent-sc12]   .chevron[_ngcontent-sc12] {
#   flex-shrink: 0;
#   position: relative;
#   width: 50px;
# }
# .sidebar-menu-block[_ngcontent-sc12]   .sidebar-menu-item[_ngcontent-sc12]   .chevron[_ngcontent-sc12]   svg[_ngcontent-sc12] {
#   position: absolute;
#   top: 0;
#   left: 0;
#   right: 0;
#   bottom: 0;
#   margin: auto;
#   width: 7px;
#   height: 13px;
#   fill: #5A626B;
# }
#   </style>
#   <style ng-transition="boliga-app">
#    .badge[_ngcontent-sc15] {
#   display: block;
#   border-radius: 30px;
#   text-align: center;
#   font-size: 13px;
#   line-height: 16px;
#   font-weight: 700;
#   color: #fff;
#   background-color: #fda326;
#   padding: 5px 7px;
#   text-overflow: ellipsis;
#   overflow: hidden;
# }
# .badge.secondary[_ngcontent-sc15] {
#   background-color: #ff4c8a;
# }
# .badge.foreclosure[_ngcontent-sc15] {
#   background-color: #6091C0;
# }
# .badge.sponsored[_ngcontent-sc15] {
#   background-color: #00AB97;
# }
# .badge.success[_ngcontent-sc15] {
#   background-color: #33CA7C;
# }
# .badge.full-height[_ngcontent-sc15] {
#   height: 100%;
#   display: -webkit-box;
#   display: flex;
#   -webkit-box-align: center;
#           align-items: center;
#   -webkit-box-pack: center;
#           justify-content: center;
# }
# @media screen and (max-width: 340px) {
#   .badge.small[_ngcontent-sc15] {
#     padding: 2px 4px;
#     font-size: 12px;
#   }
# }
#   </style>
#   <style ng-transition="boliga-app">
#    ul[_ngcontent-sc11] {
#   list-style-type: none;
#   padding: 0;
#   margin: 0;
# }
#
# li[_ngcontent-sc11] {
#   margin: 9px 0;
#   line-height: 16px;
# }
#
# a[_ngcontent-sc11] {
#   color: inherit;
# }
#
# .title[_ngcontent-sc11] {
#   font-weight: 600;
#   margin-bottom: 10px;
# }
#
# .link[_ngcontent-sc11] {
#   font-size: 14px;
#   letter-spacing: 0.25px;
# }
#
# .media[_ngcontent-sc11] {
#   display: -webkit-box;
#   display: flex;
#   -webkit-box-pack: justify;
#           justify-content: space-between;
#   margin-top: 33px;
#   -webkit-box-align: center;
#           align-items: center;
# }
#
# .media[_ngcontent-sc11]   .icon[_ngcontent-sc11] {
#   display: inline-block;
#   fill: white;
# }
#
# .media[_ngcontent-sc11]   .icon--facebook[_ngcontent-sc11] {
#   width: 8px;
#   height: 16px;
# }
#
# .media[_ngcontent-sc11]   .icon--twitter[_ngcontent-sc11] {
#   width: 16px;
#   height: 12px;
# }
#
# @media (max-width: 767.98px) {
#   .list[_ngcontent-sc11] {
#     overflow: hidden;
#     border-bottom: 1px solid rgba(255, 255, 255, 0.12);
#     opacity: 0.7;
#   }
#   .list[_ngcontent-sc11]   li[_ngcontent-sc11] {
#     padding-top: 8px;
#     padding-bottom: 24px;
#     border-top: 1px solid rgba(255, 255, 255, 0.12);
#     margin: 0;
#   }
#   .list[_ngcontent-sc11]   li[_ngcontent-sc11]:first-child {
#     border: none;
#   }
#   .list.closed[_ngcontent-sc11] {
#     display: none;
#   }
#
#   .title[_ngcontent-sc11] {
#     position: relative;
#     margin: 0;
#     font-size: 14px;
#     padding: 16px 0;
#     border-bottom: 1px solid rgba(255, 255, 255, 0.12);
#   }
#   .title--top[_ngcontent-sc11] {
#     border-top: 1px solid rgba(255, 255, 255, 0.12);
#   }
#   .title.open[_ngcontent-sc11]::before {
#     -webkit-transform: rotate(90deg);
#             transform: rotate(90deg);
#   }
#
#   .title[_ngcontent-sc11]::before, .title[_ngcontent-sc11]::after {
#     content: "";
#     position: absolute;
#     top: 0;
#     bottom: 0;
#     right: 15px;
#     margin: auto;
#     width: 2px;
#     height: 15px;
#     background-color: #fff;
#     -webkit-transition: -webkit-transform 0.2s;
#     transition: -webkit-transform 0.2s;
#     transition: transform 0.2s;
#     transition: transform 0.2s, -webkit-transform 0.2s;
#   }
#
#   .title[_ngcontent-sc11]::after {
#     -webkit-transform: rotate(90deg);
#             transform: rotate(90deg);
#   }
#
#   .media[_ngcontent-sc11] {
#     margin-top: 20px;
#   }
# }
#   </style>
#   <style ng-transition="boliga-app">
#    .search-box[_ngcontent-sc57] {
#   position: -webkit-sticky;
#   position: sticky;
#   top: 0;
#   z-index: 1004;
#   background-color: #fff;
# }
# @media (min-width: 768px) {
#   .search-box[_ngcontent-sc57] {
#     position: static;
#     background-color: unset;
#   }
# }
# .search-box[_ngcontent-sc57]   app-search-on-map-nav[_ngcontent-sc57] {
#   width: 160px;
# }
# .advanced-search-box[_ngcontent-sc57] {
#   background: linear-gradient(180deg, #fff 0%, #f7f7f7 400px);
#   padding: 25px 0 40px 0;
# }
# .housing-list-results[_ngcontent-sc57] {
#   background: #f7f7f7;
#   padding: 20px 0 10px 0;
# }
# @media (min-width: 768px) {
#   .housing-list-results[_ngcontent-sc57] {
#     padding-top: 34px;
#     background: linear-gradient(180deg, #fff 0%, #f7f7f7 400px);
#   }
# }
# .h1-title[_ngcontent-sc57] {
#   font-size: 16px;
# }
# .paragraph-text[_ngcontent-sc57] {
#   white-space: pre-line;
#   -webkit-column-count: 2;
#   -moz-column-count: 2;
#   column-count: 2;
# }
# .paragraph-text-top[_ngcontent-sc57] {
#   font-size: 12px;
# }
# .chevron-up[_ngcontent-sc57] {
#   -webkit-transform: scaleY(-1);
#           transform: scaleY(-1);
# }
#   </style>
#   <style ng-transition="boliga-app">
#    .search-params-display[_ngcontent-sc58] {
#   font-size: 12px;
#   color: #707880;
# }
#
# .search-params[_ngcontent-sc58] {
#   white-space: nowrap;
#   cursor: pointer;
# }
#
# .search-icon[_ngcontent-sc58] {
#   color: #707070;
# }
#
# .rotate-horizonal[_ngcontent-sc58] {
#   -webkit-transform: rotate(90deg);
#           transform: rotate(90deg);
# }
#
# .search-btn-group[_ngcontent-sc58] {
#   border: 1px solid #E4E4E4;
#   fill: #E4E4E4;
#   color: #000;
#   height: 55px;
# }
#
# .search-btn-group[_ngcontent-sc58]   .placeholder[_ngcontent-sc58] {
#   color: #E4E4E4;
# }
#
# .pointer[_ngcontent-sc58] {
#   cursor: pointer;
# }
#   </style>
#   <style ng-transition="boliga-app">
#    .mobile-filter-title[_ngcontent-sc59] {
#   display: -webkit-box;
#   display: flex;
#   -webkit-box-align: center;
#           align-items: center;
#   font-size: 20px;
#   margin-top: 23px;
#   margin-bottom: 35px;
# }
# @media (min-width: 768px) {
#   .mobile-filter-title[_ngcontent-sc59] {
#     display: none;
#   }
# }
# .mobile-filter-title[_ngcontent-sc59]   svg[_ngcontent-sc59] {
#   width: 7px;
#   height: 13px;
#   margin-right: 10px;
# }
# .mobile-filter-title--disabled[_ngcontent-sc59] {
#   opacity: 0.3;
#   pointer-events: none;
# }
# .filter-button[_ngcontent-sc59] {
#   display: block;
#   position: relative;
#   padding: 9px 15px;
#   background-color: #fff;
#   border: 1px solid rgba(0, 0, 0, 0.12);
#   border-radius: 3px;
#   width: 100%;
#   height: 100%;
#   font-size: 14px;
#   cursor: pointer;
# }
# .filter-button--secondary[_ngcontent-sc59] {
#   font-weight: 700;
#   background-color: #EFF8FF;
#   color: #6091C0;
#   border-color: rgba(96, 145, 192, 0.5);
# }
# .filter-button--stroked[_ngcontent-sc59] {
#   font-weight: 700;
#   background-color: white;
#   color: #5A626B;
#   border-color: rgba(0, 0, 0, 0.12);
# }
# .filter-button[_ngcontent-sc59]:disabled {
#   opacity: 0.3;
#   pointer-events: none;
# }
# .filter-label[_ngcontent-sc59] {
#   font-size: 14px;
#   font-weight: 600;
# }
# .filter-button-wrapper[_ngcontent-sc59] {
#   display: -webkit-box;
#   display: flex;
#   -webkit-box-pack: justify;
#           justify-content: space-between;
#   -webkit-box-align: center;
#           align-items: center;
#   padding: 20px 30px;
#   position: relative;
#   width: 100%;
#   max-width: 100%;
# }
# .filter-button-wrapper[_ngcontent-sc59]   .filter-button[_ngcontent-sc59] {
#   width: 125px;
# }
# .filter-button-wrapper[_ngcontent-sc59]::before {
#   content: "";
#   position: absolute;
#   width: calc(100% + 2px);
#   height: 20px;
#   top: -20px;
#   left: -1px;
#   background-image: -webkit-gradient(linear, left top, left bottom, from(rgba(255, 255, 255, 0)), to(#000000));
#   background-image: linear-gradient(180deg, rgba(255, 255, 255, 0) 0%, #000000 100%);
#   opacity: 0.15;
# }
# @supports (-ms-ime-align: auto) {
#   .filter-button-wrapper[_ngcontent-sc59]::before {
#     display: none;
#   }
# }
# @media (max-width: 767.98px) {
#   .filter-button-wrapper[_ngcontent-sc59] {
#     padding: 11px 15px;
#     flex-shrink: 0;
#     background: #fff;
#   }
#   .filter-button-wrapper[_ngcontent-sc59]   .filter-button[_ngcontent-sc59] {
#     width: 157px;
#   }
# }
# .advanced-expand-button[_ngcontent-sc59] {
#   color: #50a1de;
#   font-weight: 600;
#   display: -webkit-box;
#   display: flex;
#   -webkit-box-align: center;
#           align-items: center;
#   padding: 16px;
#   padding-left: 0;
#   font-size: 14px;
#   position: relative;
#   margin-left: 56px;
#   width: calc(100% - 56px);
# }
# .advanced-expand-button[_ngcontent-sc59]   span[_ngcontent-sc59] {
#   display: block;
#   -webkit-box-flex: 1;
#           flex-grow: 1;
# }
# .advanced-expand-button[_ngcontent-sc59]   .chevron-down[_ngcontent-sc59] {
#   fill: #50a1de;
#   width: 13px;
#   height: 7px;
#   margin-right: 16px;
# }
# .search[_ngcontent-sc59]   .search-address[_ngcontent-sc59]   .address-holder[_ngcontent-sc59] {
#   position: relative;
#   top: 0;
#   z-index: 3;
#   -webkit-transition: top 0.3s;
#   transition: top 0.3s;
# }
# @media (max-width: 767.98px) {
#   .search[_ngcontent-sc59]   .search-address[_ngcontent-sc59]   .address-holder--drift[_ngcontent-sc59] {
#     z-index: 12;
#   }
# }
# app-search-field-submit[_ngcontent-sc59] {
#   height: 55px;
# }
#   </style>
#   <style ng-transition="boliga-app">
#    .found-listings-title[_ngcontent-sc61] {
#   font-size: 14px;
#   line-height: 15px;
# }
#
# .zip-title[_ngcontent-sc61] {
#   font-size: 14px;
#   line-height: 16px;
# }
#
# .save-search-button[_ngcontent-sc61] {
#   font-weight: 500;
#   background-color: white;
#   color: #5A626B;
#   padding-top: 5px;
#   padding-bottom: 5px;
# }
#
# .save-search-button--active[_ngcontent-sc61], .save-search-button[_ngcontent-sc61]:hover {
#   color: white;
#   background-color: #FDA326;
# }
#
# .save-search-button[_ngcontent-sc61]   svg[_ngcontent-sc61] {
#   width: 13px;
# }
#
# @media (max-width: 767.98px) {
#   .housing-list-results--item[_ngcontent-sc61]:not(:first-of-type) {
#     display: none;
#   }
# }
#
# .sort-box[_ngcontent-sc61] {
#   background: #f1f1f1;
# }
#
# @media (max-width: 767.98px) {
#   .sort-box[_ngcontent-sc61] {
#     background: unset;
#   }
# }
#   </style>
#   <style ng-transition="boliga-app">
#    app-button.app-search-field-submit > .app-button {
#   width: 160px;
#   font-size: 16px;
#   letter-spacing: 0.13px;
#   border-radius: 0 0.1875rem 0.1875rem 0;
# }
# @media (max-width: 767.98px) {
#   app-button.app-search-field-submit > .app-button {
#     width: 90px;
#   }
# }
# .app-search-on-map-nav.searchmap .app-button {
#   background: #6091c0 !important;
#   color: #fff;
# }
# .app-search-on-map-nav.searchmap .app-button:hover {
#   background: #3566ac !important;
# }
#   </style>
#   <style ng-transition="boliga-app">
#    .mobile-filter-title[_ngcontent-sc9] {
#   display: -webkit-box;
#   display: flex;
#   -webkit-box-align: center;
#           align-items: center;
#   font-size: 20px;
#   margin-top: 23px;
#   margin-bottom: 35px;
# }
# @media (min-width: 768px) {
#   .mobile-filter-title[_ngcontent-sc9] {
#     display: none;
#   }
# }
# .mobile-filter-title[_ngcontent-sc9]   svg[_ngcontent-sc9] {
#   width: 7px;
#   height: 13px;
#   margin-right: 10px;
# }
# .mobile-filter-title--disabled[_ngcontent-sc9] {
#   opacity: 0.3;
#   pointer-events: none;
# }
# .filter-button[_ngcontent-sc9] {
#   display: block;
#   position: relative;
#   padding: 9px 15px;
#   background-color: #fff;
#   border: 1px solid rgba(0, 0, 0, 0.12);
#   border-radius: 3px;
#   width: 100%;
#   height: 100%;
#   font-size: 14px;
#   cursor: pointer;
# }
# .filter-button--secondary[_ngcontent-sc9] {
#   font-weight: 700;
#   background-color: #EFF8FF;
#   color: #6091C0;
#   border-color: rgba(96, 145, 192, 0.5);
# }
# .filter-button--stroked[_ngcontent-sc9] {
#   font-weight: 700;
#   background-color: white;
#   color: #5A626B;
#   border-color: rgba(0, 0, 0, 0.12);
# }
# .filter-button[_ngcontent-sc9]:disabled {
#   opacity: 0.3;
#   pointer-events: none;
# }
# .filter-label[_ngcontent-sc9] {
#   font-size: 14px;
#   font-weight: 600;
# }
# .filter-button-wrapper[_ngcontent-sc9] {
#   display: -webkit-box;
#   display: flex;
#   -webkit-box-pack: justify;
#           justify-content: space-between;
#   -webkit-box-align: center;
#           align-items: center;
#   padding: 20px 30px;
#   position: relative;
#   width: 100%;
#   max-width: 100%;
# }
# .filter-button-wrapper[_ngcontent-sc9]   .filter-button[_ngcontent-sc9] {
#   width: 125px;
# }
# .filter-button-wrapper[_ngcontent-sc9]::before {
#   content: "";
#   position: absolute;
#   width: calc(100% + 2px);
#   height: 20px;
#   top: -20px;
#   left: -1px;
#   background-image: -webkit-gradient(linear, left top, left bottom, from(rgba(255, 255, 255, 0)), to(#000000));
#   background-image: linear-gradient(180deg, rgba(255, 255, 255, 0) 0%, #000000 100%);
#   opacity: 0.15;
# }
# @supports (-ms-ime-align: auto) {
#   .filter-button-wrapper[_ngcontent-sc9]::before {
#     display: none;
#   }
# }
# @media (max-width: 767.98px) {
#   .filter-button-wrapper[_ngcontent-sc9] {
#     padding: 11px 15px;
#     flex-shrink: 0;
#     background: #fff;
#   }
#   .filter-button-wrapper[_ngcontent-sc9]   .filter-button[_ngcontent-sc9] {
#     width: 157px;
#   }
# }
# .advanced-expand-button[_ngcontent-sc9] {
#   color: #50a1de;
#   font-weight: 600;
#   display: -webkit-box;
#   display: flex;
#   -webkit-box-align: center;
#           align-items: center;
#   padding: 16px;
#   padding-left: 0;
#   font-size: 14px;
#   position: relative;
#   margin-left: 56px;
#   width: calc(100% - 56px);
# }
# .advanced-expand-button[_ngcontent-sc9]   span[_ngcontent-sc9] {
#   display: block;
#   -webkit-box-flex: 1;
#           flex-grow: 1;
# }
# .advanced-expand-button[_ngcontent-sc9]   .chevron-down[_ngcontent-sc9] {
#   fill: #50a1de;
#   width: 13px;
#   height: 7px;
#   margin-right: 16px;
# }
# .filter-dropdown-wrapper[_ngcontent-sc9] {
#   position: absolute;
#   z-index: 11;
#   background-color: #fff;
#   border-radius: 3px;
#   box-shadow: 0 40px 65px rgba(0, 0, 0, 0.45);
#   border: 1px solid rgba(0, 0, 0, 0.05);
#   margin-top: 20px;
# }
# .filter-dropdown-wrapper.price[_ngcontent-sc9] {
#   right: 0px !important;
# }
# .filter-dropdown-wrapper[_ngcontent-sc9]::before {
#   content: "";
#   position: absolute;
#   top: -8px;
#   left: 16px;
#   width: 16px;
#   height: 16px;
#   border-top: 1px solid rgba(0, 0, 0, 0.05);
#   border-left: 1px solid rgba(0, 0, 0, 0.05);
#   background-color: white;
#   -webkit-transform: rotate(45deg);
#           transform: rotate(45deg);
# }
# .filter-dropdown-wrapper.price[_ngcontent-sc9]::before {
#   left: auto;
#   right: 16px;
# }
# .filter-button[_ngcontent-sc9] {
#   white-space: nowrap;
#   display: block;
#   position: relative;
#   padding: 9px 14px;
#   background-color: #fff;
#   color: #000;
#   border: 1px solid rgba(0, 0, 0, 0.12);
#   border-radius: 3px;
#   width: 100%;
#   height: 100%;
#   font-size: 13px;
#   cursor: pointer;
# }
# .filter-button--highlight[_ngcontent-sc9] {
#   background-color: #EFF8FF;
#   color: #6091C0;
#   border-color: rgba(96, 145, 192, 0.5);
#   font-weight: 600;
# }
# .filter-button--primary[_ngcontent-sc9] {
#   font-weight: 700;
#   background-color: #6091C0;
#   color: white;
#   border-color: transparent;
#   letter-spacing: 0.14px;
# }
# .filter-button--stroked[_ngcontent-sc9] {
#   font-weight: 700;
#   background-color: white;
#   color: #5A626B;
#   border-color: rgba(0, 0, 0, 0.12);
# }
# .filter-container[_ngcontent-sc9] {
#   display: -webkit-box;
#   display: flex;
#   min-height: 40px;
# }
# .filter-container[_ngcontent-sc9]   .desktop-button-wrapper[_ngcontent-sc9] {
#   position: relative;
#   margin-right: 10px;
#   flex-shrink: 0;
# }
# .filter-container[_ngcontent-sc9]   .spacer[_ngcontent-sc9] {
#   -webkit-box-flex: 1;
#           flex: 1 1 auto;
# }
# .filter-container--mobile[_ngcontent-sc9] {
#   display: none;
# }
# .filter-container[_ngcontent-sc9]   .map-button[_ngcontent-sc9] {
#   width: 160px;
# }
# .filter-container[_ngcontent-sc9]   .map-button[_ngcontent-sc9]   svg[_ngcontent-sc9] {
#   width: 10px;
#   height: 13px;
#   margin-right: 5px;
#   fill: #5A626B;
# }
# .filter-container--mobile[_ngcontent-sc9] {
#   display: none;
# }
# @media (max-width: 767.98px) {
#   .filter-container--desktop[_ngcontent-sc9] {
#     display: none;
#   }
#
#   .mobile-advanced-container[_ngcontent-sc9] {
#     overflow: hidden;
#   }
#
#   .filter-container--mobile[_ngcontent-sc9] {
#     display: -webkit-box;
#     display: flex;
#     -webkit-box-orient: vertical;
#     -webkit-box-direction: normal;
#             flex-flow: column nowrap;
#     -webkit-box-pack: justify;
#             justify-content: space-between;
#   }
#   .filter-container--mobile[_ngcontent-sc9]   .list-unstyled[_ngcontent-sc9] {
#     list-style-type: none;
#     margin: 0 -14px;
#     background: #fff;
#     border-top: 1px solid rgba(0, 0, 0, 0.12);
#     border-bottom: 1px solid rgba(0, 0, 0, 0.12);
#   }
#   .filter-container--mobile[_ngcontent-sc9]   .list-unstyled.advancedFiltersActive[_ngcontent-sc9] {
#     padding-bottom: 75px;
#   }
#   .filter-container--mobile[_ngcontent-sc9]   .list-unstyled[_ngcontent-sc9]   .mobile-button[_ngcontent-sc9] {
#     display: -webkit-box;
#     display: flex;
#     -webkit-box-align: center;
#             align-items: center;
#     padding: 16px;
#     padding-left: 0;
#     border-bottom: 1px solid rgba(0, 0, 0, 0.12);
#     font-size: 14px;
#     color: black;
#     position: relative;
#     margin-left: 56px;
#     width: calc(100% - 56px);
#   }
#   .filter-container--mobile[_ngcontent-sc9]   .list-unstyled[_ngcontent-sc9]   .mobile-button[_ngcontent-sc9]   span[_ngcontent-sc9] {
#     display: block;
#     margin-left: 20px;
#     -webkit-box-flex: 1;
#             flex-grow: 1;
#   }
#   .filter-container--mobile[_ngcontent-sc9]   .list-unstyled[_ngcontent-sc9]   .mobile-button[_ngcontent-sc9]   .chevron-right[_ngcontent-sc9] {
#     height: 13px;
#     width: 7px;
#     fill: #939ca9;
#     margin-right: 16px;
#   }
#   .filter-container--mobile[_ngcontent-sc9]   .list-unstyled[_ngcontent-sc9]   .mobile-button[_ngcontent-sc9]   .mobile-button-icon[_ngcontent-sc9] {
#     max-width: 20px;
#     max-height: 20px;
#     stroke: #5A626B;
#     fill: #5A626B;
#     flex-shrink: 0;
#   }
#   .filter-container--mobile[_ngcontent-sc9]   .list-unstyled[_ngcontent-sc9]   .mobile-button[_ngcontent-sc9]   .clear[_ngcontent-sc9] {
#     position: absolute;
#     top: 0;
#     bottom: 0;
#     margin: auto;
#     left: -30px;
#     width: 12px;
#     height: 12px;
#     fill: #5A626B;
#     stroke: #5A626B;
#     opacity: 0.5;
#   }
#   .filter-container--mobile[_ngcontent-sc9]   .list-unstyled[_ngcontent-sc9]   .mobile-button.highlight[_ngcontent-sc9]   span[_ngcontent-sc9] {
#     font-weight: 600;
#   }
#   .filter-container--mobile[_ngcontent-sc9]   .list-unstyled[_ngcontent-sc9]   .mobile-button.highlight[_ngcontent-sc9]   .mobile-button-icon[_ngcontent-sc9] {
#     stroke: #33ca7c;
#     fill: #33ca7c;
#   }
#   .filter-container--mobile[_ngcontent-sc9]   .list-unstyled[_ngcontent-sc9]   .mobile-filter-panel[_ngcontent-sc9] {
#     position: fixed;
#     top: 0;
#     left: 0;
#     right: 0;
#     bottom: 0;
#     background-color: #fff;
#     z-index: 99;
#     display: -webkit-box;
#     display: flex;
#     -webkit-box-orient: vertical;
#     -webkit-box-direction: normal;
#             flex-direction: column;
#   }
#   .filter-container--mobile[_ngcontent-sc9]   .list-unstyled[_ngcontent-sc9]   .mobile-filter-panel[_ngcontent-sc9]    > *[_ngcontent-sc9] {
#     height: 100%;
#     display: -webkit-box;
#     display: flex;
#     -webkit-box-orient: vertical;
#     -webkit-box-direction: normal;
#             flex-direction: column;
#   }
#   .filter-container--mobile[_ngcontent-sc9]   .list-unstyled[_ngcontent-sc9]:last-of-type {
#     border-bottom: none;
#   }
#   .filter-container--mobile[_ngcontent-sc9]   .list-unstyled[_ngcontent-sc9]   .chevron-down[_ngcontent-sc9] {
#     fill: #50a1de;
#     width: 13px;
#     height: 7px;
#     margin-right: 16px;
#   }
#   .filter-container--mobile[_ngcontent-sc9]   .mobile-submit-buttons[_ngcontent-sc9] {
#     display: -webkit-box;
#     display: flex;
#     position: fixed;
#     bottom: 10px;
#     left: 14px;
#     right: 14px;
#   }
#   .filter-container--mobile[_ngcontent-sc9]   .mobile-submit-buttons[_ngcontent-sc9]   .filter-button[_ngcontent-sc9] {
#     -webkit-box-flex: 1;
#             flex: 1 0 40%;
#   }
#   .filter-container--mobile[_ngcontent-sc9]   .mobile-submit-buttons[_ngcontent-sc9]   .filter-button[_ngcontent-sc9]   .total-count[_ngcontent-sc9] {
#     margin-left: 3px;
#   }
#   .filter-container--mobile[_ngcontent-sc9]   .mobile-submit-buttons[_ngcontent-sc9]   .filter-button[_ngcontent-sc9]:first-of-type {
#     margin-right: 16px;
#   }
# }
#   </style>
#   <style ng-transition="boliga-app">
#    .app-search-on-map-nav[_ngcontent-sc67] {
#   width: 160px;
# }
# .app-search-on-map-nav[_ngcontent-sc67]   svg[_ngcontent-sc67] {
#   width: 10px;
#   height: 13px;
#   fill: #fff;
# }
# .app-search-on-map-nav[_ngcontent-sc67]   svg[_ngcontent-sc67]    + span[_ngcontent-sc67] {
#   margin-left: 5px;
# }
#   </style>
#   <style ng-transition="boliga-app">
#    .search-field[_ngcontent-sc70] {
#   box-shadow: 0 4px 6px rgba(0, 0, 0, 0.06);
#   z-index: 5;
#   position: relative;
# }
# .search-field[_ngcontent-sc70]   .search-input-holder[_ngcontent-sc70] {
#   display: -webkit-box;
#   display: flex;
#   height: 55px;
#   background: #fff;
#   border-radius: 3px 0 0 3px;
#   border: 1px solid rgba(0, 0, 0, 0.12);
# }
# .search-field[_ngcontent-sc70]   .search-input-holder[_ngcontent-sc70]   app-search-tag-list[_ngcontent-sc70] {
#   height: 100%;
#   flex-shrink: 0;
# }
# .search-field[_ngcontent-sc70]   .search-input-holder[_ngcontent-sc70]   app-search-tag-list[_ngcontent-sc70]    ~ .search-input-container[_ngcontent-sc70]   .search-autocomplete-text[_ngcontent-sc70], .search-field[_ngcontent-sc70]   .search-input-holder[_ngcontent-sc70]   app-search-tag-list[_ngcontent-sc70]    ~ .search-input-container[_ngcontent-sc70]   .search-input[_ngcontent-sc70] {
#   padding-left: 10px;
# }
# .search-field[_ngcontent-sc70]   .search-input-holder[_ngcontent-sc70]   app-search-tag-list[_ngcontent-sc70]    ~ .icon-search[_ngcontent-sc70] {
#   display: none;
# }
# .search-field[_ngcontent-sc70]   .search-input-holder[_ngcontent-sc70]   .search-input[_ngcontent-sc70] {
#   z-index: 3;
#   position: relative;
#   border: 0;
#   width: 100%;
#   height: 100%;
#   line-height: 100%;
#   color: black;
#   background: #fff;
#   font-size: 1rem;
#   font-weight: 500;
#   padding: 0 0 0 47px;
#   -webkit-transition: color 0.15s;
#   transition: color 0.15s;
# }
# .search-field[_ngcontent-sc70]   .search-input-holder[_ngcontent-sc70]   .search-input[_ngcontent-sc70]:focus {
#   color: #000;
# }
# .search-field[_ngcontent-sc70]   .search-input-holder[_ngcontent-sc70]   .search-input[_ngcontent-sc70]:focus    ~ .icon-search[_ngcontent-sc70] {
#   fill: #000;
# }
# .search-field[_ngcontent-sc70]   .search-input-holder[_ngcontent-sc70]   .search-input[_ngcontent-sc70]::-ms-clear {
#   display: none;
# }
# .search-field[_ngcontent-sc70]   .search-input-holder[_ngcontent-sc70]   .search-input-container[_ngcontent-sc70] {
#   position: relative;
#   height: 100%;
#   width: 100%;
# }
# .search-field[_ngcontent-sc70]   .search-input-holder[_ngcontent-sc70]   .search-autocomplete-text[_ngcontent-sc70] {
#   z-index: 4;
#   position: absolute;
#   width: 100%;
#   height: 100%;
#   padding: 0 0 0 48px;
#   font-size: 1rem;
#   font-weight: 500;
#   color: #5a626b;
#   white-space: nowrap;
#   display: -webkit-box;
#   display: flex;
#   -webkit-box-align: center;
#           align-items: center;
#   pointer-events: none;
#   overflow: hidden;
# }
# .search-field[_ngcontent-sc70]   .search-input-holder[_ngcontent-sc70]   .search-autocomplete-text[_ngcontent-sc70]   .invisible[_ngcontent-sc70] {
#   color: transparent;
# }
# .search-field[_ngcontent-sc70]   .search-input-holder[_ngcontent-sc70]   .icon-search[_ngcontent-sc70] {
#   z-index: 4;
#   position: absolute;
#   top: 0;
#   left: 16px;
#   bottom: 0;
#   width: 16px;
#   fill: #5a626b;
#   pointer-events: none;
#   -webkit-transition: fill 0.15s;
#   transition: fill 0.15s;
# }
# .anchor[_ngcontent-sc70] {
#   cursor: pointer;
# }
# .search-field-flat[_nghost-sc70]   .search-field[_ngcontent-sc70] {
#   box-shadow: none;
# }
# .search-field-flat[_nghost-sc70]   .search-field[_ngcontent-sc70]   .search-input-holder[_ngcontent-sc70] {
#   border-radius: 3px;
#   height: 45px;
# }
# .search-field-flat[_nghost-sc70]   .search-field[_ngcontent-sc70]   .search-input-holder[_ngcontent-sc70]   .search-autocomplete-text[_ngcontent-sc70], .search-field-flat[_nghost-sc70]   .search-field[_ngcontent-sc70]   .search-input-holder[_ngcontent-sc70]   .search-input[_ngcontent-sc70] {
#   line-height: normal;
#   font-size: 0.875rem;
# }
#   </style>
#   <style ng-transition="boliga-app">
#    .app-button[_ngcontent-sc48] {
#   width: 100%;
#   height: 100%;
#   color: #000;
#   background-color: #fff;
#   border-radius: 0.1875rem;
#   border: 1px solid rgba(0, 0, 0, 0.12);
#   padding: 11px 15px;
#   font-size: 14px;
#   line-height: 16px;
#   cursor: pointer;
#   -webkit-transition: background 0.15s;
#   transition: background 0.15s;
# }
# .app-button[_ngcontent-sc48]   .button-flex-wrapper[_ngcontent-sc48] {
#
#   display: -webkit-box;
#   display: flex;
#   -webkit-box-align: center;
#           align-items: center;
#   -webkit-box-pack: center;
#           justify-content: center;
# }
# .app-button.primary[_ngcontent-sc48] {
#   font-weight: bolder;
#   background-color: #6091C0;
#   color: white;
#   border-color: transparent;
#   letter-spacing: 0.14px;
# }
# .app-button.primary[_ngcontent-sc48]:hover {
#   background-color: #3566ac;
# }
# .app-button.primary--alt[_ngcontent-sc48] {
#   font-weight: bolder;
#   background-color: #939ca9;
#   color: white;
#   border-color: transparent;
#   letter-spacing: normal;
# }
# .app-button.secondary[_ngcontent-sc48] {
#   font-weight: bolder;
#   background-color: #EFF8FF;
#   color: #6091C0;
#   border-color: rgba(96, 145, 192, 0.5);
#   letter-spacing: normal;
# }
# .app-button.secondary[_ngcontent-sc48]:hover {
#   background-color: #d0eaff;
# }
# .app-button.stroked[_ngcontent-sc48] {
#   font-weight: bolder;
#   background-color: transparent;
#   color: #5A626B;
#   border-color: rgba(0, 0, 0, 0.12);
#   letter-spacing: normal;
# }
# .app-button.tab[_ngcontent-sc48] {
#   font-weight: bolder;
#   background-color: rgba(0, 0, 0, 0.6);
#   color: white;
#   border-color: transparent;
#   letter-spacing: normal;
# }
# .app-button.accent[_ngcontent-sc48] {
#   font-weight: bolder;
#   color: #6091C0;
# }
# .app-button[_ngcontent-sc48]   .icon[_ngcontent-sc48] {
#   position: relative;
#   width: 16px;
#   height: 16px;
#   margin-right: 9px;
# }
# .app-button[_ngcontent-sc48]   .icon[_ngcontent-sc48]   svg[_ngcontent-sc48] {
#   position: absolute;
#   top: 0;
#   left: 0;
#   right: 0;
#   bottom: 0;
#   margin: auto;
# }
# .app-button.semiBold[_ngcontent-sc48] {
#   font-weight: 600;
# }
# .app-button.bold[_ngcontent-sc48] {
#   font-weight: bolder;
# }
# .app-button.font-medium[_ngcontent-sc48] {
#   font-size: 16px;
#   line-height: 17px;
# }
# .app-button.font-large[_ngcontent-sc48] {
#   font-size: 19px;
#   line-height: 21px;
# }
# .app-button.no-padding[_ngcontent-sc48] {
#   padding: 0;
# }
# .app-button.append[_ngcontent-sc48] {
#   -webkit-box-orient: horizontal;
#   -webkit-box-direction: reverse;
#           flex-direction: row-reverse;
# }
# .app-button.append[_ngcontent-sc48]   .icon[_ngcontent-sc48] {
#   margin: 0;
#   margin-left: 9px;
# }
# .app-button.search-on-map[_ngcontent-sc48] {
#   background: #6091c0;
#   color: #fff;
# }
# .app-button.search-on-map[_ngcontent-sc48]:hover {
#   background: #3566ac;
# }
#   </style>
#   <style ng-transition="boliga-app">
#    .spacer[_ngcontent-sc60] {
#   -webkit-box-flex: 1;
#           flex: 1 1 auto;
# }
#
# .recent[_ngcontent-sc60] {
#   background-color: #fff;
#   padding: 12px 30px;
#   padding-top: 5px;
#   box-shadow: 0 7px 10px rgba(0, 0, 0, 0.05);
#   border-radius: 6px;
# }
#
# .recent[_ngcontent-sc60]   .header[_ngcontent-sc60] {
#   display: -webkit-box;
#   display: flex;
#   -webkit-box-align: end;
#           align-items: flex-end;
# }
#
# .recent[_ngcontent-sc60]   .header[_ngcontent-sc60]    > *[_ngcontent-sc60] {
#   color: #5A626B;
#   font-weight: 600;
#   text-transform: uppercase;
#   font-size: 10px;
# }
#
# .recent[_ngcontent-sc60]   .header[_ngcontent-sc60]   h6[_ngcontent-sc60] {
#   margin: 0;
#   padding-bottom: 5px;
# }
#
# .recent[_ngcontent-sc60]   ul[_ngcontent-sc60] {
#   padding: 0;
#   margin: 0;
#   list-style-type: none;
# }
#
# .recent[_ngcontent-sc60]   ul[_ngcontent-sc60]   li[_ngcontent-sc60] {
#   display: -webkit-box;
#   display: flex;
#   -webkit-box-align: center;
#           align-items: center;
#   padding: 13px 0;
#   font-size: 14px;
#   border-top: 1px solid rgba(151, 151, 151, 0.12);
#   position: relative;
# }
#
# .recent[_ngcontent-sc60]   ul[_ngcontent-sc60]   li[_ngcontent-sc60]   app-tooltip[_ngcontent-sc60] {
#   display: -webkit-inline-box;
#   display: inline-flex;
#   max-width: 60%;
# }
#
# .recent[_ngcontent-sc60]   ul[_ngcontent-sc60]   li[_ngcontent-sc60]   .name[_ngcontent-sc60] {
#   font-weight: 600;
#   margin-right: 5px;
#   display: inline-block;
#   overflow: hidden;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   color: black;
# }
#
# .recent[_ngcontent-sc60]   ul[_ngcontent-sc60]   li[_ngcontent-sc60]:last-child {
#   padding-bottom: 0;
# }
#
# .recent[_ngcontent-sc60]   .badge-wrapper[_ngcontent-sc60] {
#   display: -webkit-box;
#   display: flex;
#   -webkit-box-align: center;
#           align-items: center;
#   -webkit-box-pack: end;
#           justify-content: flex-end;
#   cursor: pointer;
# }
#
# .recent[_ngcontent-sc60]   .badge-wrapper[_ngcontent-sc60]   .badge[_ngcontent-sc60] {
#   display: -webkit-inline-box;
#   display: inline-flex;
#   -webkit-box-align: center;
#           align-items: center;
#   -webkit-box-pack: center;
#           justify-content: center;
#   min-width: 50px;
#   height: 30px;
# }
#
# .recent[_ngcontent-sc60]   .badge-wrapper[_ngcontent-sc60]:last-child {
#   min-width: 155px;
# }
#
# .recent.smaller[_ngcontent-sc60] {
#   background-color: transparent;
#   border: none;
#   padding: 0;
#   box-shadow: none;
#   margin: 0;
# }
#
# .recent.smaller[_ngcontent-sc60]   .header[_ngcontent-sc60] {
#   line-height: 10px;
# }
#
# .recent.smaller[_ngcontent-sc60]   .header[_ngcontent-sc60]   h6[_ngcontent-sc60] {
#   width: 80px;
# }
#
# .recent.smaller[_ngcontent-sc60]   ul[_ngcontent-sc60]   li[_ngcontent-sc60] {
#   padding: 3px 0;
# }
#
# .recent.smaller[_ngcontent-sc60]   ul[_ngcontent-sc60]   li[_ngcontent-sc60]   app-tooltip[_ngcontent-sc60] {
#   max-width: 40%;
# }
#
# .recent.smaller[_ngcontent-sc60]   ul[_ngcontent-sc60]   li[_ngcontent-sc60]:last-child {
#   border-bottom: 1px solid rgba(151, 151, 151, 0.12);
# }
#
# .recent.smaller[_ngcontent-sc60]   .badge-wrapper[_ngcontent-sc60]   .selection-title[_ngcontent-sc60] {
#   -webkit-box-orient: vertical;
#   -webkit-box-direction: normal;
#           flex-flow: column nowrap;
#   -webkit-box-align: end;
#           align-items: flex-end;
# }
#
# .recent.smaller[_ngcontent-sc60]   .badge-wrapper[_ngcontent-sc60]   .selection-title[_ngcontent-sc60]   span[_ngcontent-sc60]:first-child {
#   margin: 0;
# }
#
# .recent.smaller[_ngcontent-sc60]   .badge-wrapper[_ngcontent-sc60]:last-child {
#   min-width: 90px;
# }
#
# @media (max-width: 767.98px) {
#   .recent[_ngcontent-sc60]:not(.smaller) {
#     padding: 0 20px;
#   }
#   .recent[_ngcontent-sc60]:not(.smaller)   .header[_ngcontent-sc60] {
#     line-height: 10px;
#   }
#   .recent[_ngcontent-sc60]:not(.smaller)   .header[_ngcontent-sc60]   h6[_ngcontent-sc60] {
#     width: 80px;
#   }
#   .recent[_ngcontent-sc60]:not(.smaller)   ul[_ngcontent-sc60]   li[_ngcontent-sc60] {
#     padding: 15px 0;
#   }
#   .recent[_ngcontent-sc60]:not(.smaller)   ul[_ngcontent-sc60]   li[_ngcontent-sc60]   app-tooltip[_ngcontent-sc60] {
#     max-width: 40%;
#   }
#   .recent[_ngcontent-sc60]:not(.smaller)   ul[_ngcontent-sc60]   li[_ngcontent-sc60]:nth-child(n+3) {
#     display: none;
#   }
#   .recent[_ngcontent-sc60]:not(.smaller)   .badge-wrapper[_ngcontent-sc60] {
#     margin-right: 10px;
#   }
#   .recent[_ngcontent-sc60]:not(.smaller)   .badge-wrapper[_ngcontent-sc60]   .selection-title[_ngcontent-sc60] {
#     -webkit-box-orient: vertical;
#     -webkit-box-direction: normal;
#             flex-flow: column nowrap;
#     -webkit-box-align: end;
#             align-items: flex-end;
#   }
#   .recent[_ngcontent-sc60]:not(.smaller)   .badge-wrapper[_ngcontent-sc60]   .selection-title[_ngcontent-sc60]   span[_ngcontent-sc60]:first-child {
#     margin: 0;
#   }
#   .recent[_ngcontent-sc60]:not(.smaller)   .badge-wrapper[_ngcontent-sc60]:last-child {
#     margin-right: 0;
#     min-width: 95px;
#   }
# }
#   </style>
#   <style ng-transition="boliga-app">
#    label[_ngcontent-sc38] {
#   display: -webkit-box;
#   display: flex;
#   -webkit-box-align: center;
#           align-items: center;
#   margin: 0;
# }
# label[_ngcontent-sc38]   .icon[_ngcontent-sc38] {
#   border-radius: 100%;
#   background-color: #d8d8d8;
#   width: 22px;
#   min-width: 22px;
#   height: 22px;
#   display: -webkit-box;
#   display: flex;
#   -webkit-box-align: center;
#           align-items: center;
#   -webkit-box-pack: center;
#           justify-content: center;
#   font-weight: 700;
#   font-size: 13px;
#   text-transform: uppercase;
#   color: white;
#   margin-right: 5px;
#   -webkit-user-select: none;
#      -moz-user-select: none;
#       -ms-user-select: none;
#           user-select: none;
# }
# label[_ngcontent-sc38]   .text[_ngcontent-sc38] {
#   font-weight: 500;
#   color: #5A626B;
#   font-size: 14px;
# }
# label.hide-text[_ngcontent-sc38]   .text[_ngcontent-sc38] {
#   display: none;
# }
# label.hide-text[_ngcontent-sc38]   .icon[_ngcontent-sc38] {
#   margin: 0;
# }
# @media (max-width: 991.98px) {
#   label.hide-text-md[_ngcontent-sc38]   .text[_ngcontent-sc38] {
#     display: none;
#   }
#   label.hide-text-md[_ngcontent-sc38]   .icon[_ngcontent-sc38] {
#     margin: 0;
#   }
# }
# label.smaller[_ngcontent-sc38]   .icon[_ngcontent-sc38] {
#   width: 20px;
#   min-width: 20px;
#   height: 20px;
# }
# label.smaller[_ngcontent-sc38]   .text[_ngcontent-sc38] {
#   font-weight: 400;
# }
# label.mini[_ngcontent-sc38]   .icon[_ngcontent-sc38] {
#   width: 16px;
#   min-width: 16px;
#   height: 16px;
#   font-size: 11px;
# }
# label.mini[_ngcontent-sc38]   .text[_ngcontent-sc38] {
#   font-weight: 400;
# }
# label.bold[_ngcontent-sc38]   .text[_ngcontent-sc38] {
#   font-weight: 700;
# }
# label.property-1[_ngcontent-sc38]   .icon[_ngcontent-sc38] {
#   background: #cc1f1f;
# }
# label.property-2[_ngcontent-sc38]   .icon[_ngcontent-sc38] {
#   background: #31a32e;
# }
# label.property-3[_ngcontent-sc38]   .icon[_ngcontent-sc38] {
#   background: #4c91f9;
# }
# label.property-4[_ngcontent-sc38]   .icon[_ngcontent-sc38] {
#   background: #fcb814;
# }
# label.property-5[_ngcontent-sc38]   .icon[_ngcontent-sc38] {
#   background: #147c83;
# }
# label.property-6[_ngcontent-sc38]   .icon[_ngcontent-sc38] {
#   background: #785832;
# }
# label.property-7[_ngcontent-sc38]   .icon[_ngcontent-sc38] {
#   background: #76338e;
# }
# label.property-8[_ngcontent-sc38]   .icon[_ngcontent-sc38] {
#   background: #cc830f;
# }
# label.property-9[_ngcontent-sc38]   .icon[_ngcontent-sc38] {
#   background: #2232ad;
# }
# label.property-10[_ngcontent-sc38]   .icon[_ngcontent-sc38] {
#   background: #b9b9b9;
# }
#   </style>
#   <style ng-transition="boliga-app">
#    [_nghost-sc39] {
#   position: relative;
# }
# [_nghost-sc39]   .app-tooltip[_ngcontent-sc39] {
#   position: absolute;
#   bottom: calc(100% + 5px);
#   background: rgba(0, 0, 0, 0.8);
#   min-width: 100px;
#   max-width: 500px;
#   left: 50%;
#   -webkit-transform: translateX(-50%);
#           transform: translateX(-50%);
#   padding: 9px 10px;
#   margin: 0;
#   border-radius: 3px;
#   -webkit-box-align: center;
#           align-items: center;
#   -webkit-box-pack: center;
#           justify-content: center;
#   font-weight: 600;
#   font-size: 10px;
#   text-align: center;
#   color: #fff;
#   z-index: -1;
#   line-height: 14px;
#   opacity: 0;
#   -webkit-transition: 0s;
#   transition: 0s;
#   display: -webkit-box;
#   display: flex;
#   pointer-events: none;
# }
# [_nghost-sc39]:hover   .app-tooltip[_ngcontent-sc39] {
#   opacity: 1;
#   pointer-events: all;
#   -webkit-transition-delay: 1s;
#           transition-delay: 1s;
#   z-index: 10;
# }
# .wrap-text[_nghost-sc39]   .app-tooltip[_ngcontent-sc39] {
#   white-space: normal;
# }
# .tooltip-nowrap[_nghost-sc39]   .app-tooltip[_ngcontent-sc39] {
#   white-space: nowrap;
# }
# .tooltip-wider[_nghost-sc39]   .app-tooltip[_ngcontent-sc39] {
#   width: 200px;
# }
# .tooltip-wider[_nghost-sc39]   .app-tooltip[_ngcontent-sc39] {
#   width: 200px;
# }
# .tooltip-wide[_nghost-sc39]   .app-tooltip[_ngcontent-sc39] {
#   width: 80vw;
# }
# .tooltip-right[_nghost-sc39]   .app-tooltip[_ngcontent-sc39] {
#   top: 0;
#   bottom: 0;
#   right: 0;
#   left: calc(100% + 5px);
#   -webkit-transform: translateX(0);
#           transform: translateX(0);
# }
# .tooltip-top-left[_nghost-sc39]   .app-tooltip[_ngcontent-sc39] {
#   left: auto;
#   -webkit-transform: translateX(0);
#           transform: translateX(0);
#   right: 0;
# }
# @media (max-width: 991.98px) {
#   .md-right[_nghost-sc39]   .app-tooltip[_ngcontent-sc39] {
#     left: auto;
#     -webkit-transform: translateX(0);
#             transform: translateX(0);
#     right: 0;
#   }
# }
#   </style>
#   <style ng-transition="boliga-app">
#    .pagination[_ngcontent-sc69] {
#   -webkit-user-select: none;
#      -moz-user-select: none;
#       -ms-user-select: none;
#           user-select: none;
#   display: -webkit-box;
#   display: flex;
#   min-height: -webkit-min-content;
#   min-height: -moz-min-content;
#   min-height: min-content;
#   -webkit-box-pack: center;
#           justify-content: center;
#   width: 100%;
#   font-size: 14px;
#   font-weight: 500;
#   color: #5a626b;
# }
# .pagination[_ngcontent-sc69]   .pages[_ngcontent-sc69] {
#   display: -webkit-box;
#   display: flex;
# }
# .pagination[_ngcontent-sc69]   .nav-left[_ngcontent-sc69], .pagination[_ngcontent-sc69]   .nav-right[_ngcontent-sc69] {
#   display: -webkit-box;
#   display: flex;
# }
# .pagination[_ngcontent-sc69]   .nav-left[_ngcontent-sc69]   .jump-to-page[_ngcontent-sc69], .pagination[_ngcontent-sc69]   .nav-right[_ngcontent-sc69]   .jump-to-page[_ngcontent-sc69] {
#   display: -webkit-box;
#   display: flex;
#   -webkit-box-orient: horizontal;
#   -webkit-box-direction: normal;
#           flex-direction: row;
#   -webkit-box-align: center;
#           align-items: center;
# }
# .pagination[_ngcontent-sc69]   .page-button[_ngcontent-sc69] {
#   background-color: #fff;
#   color: #5a626b;
#   border-radius: 3px;
#   border: 1px solid rgba(0, 0, 0, 0.12);
#   height: 37px;
#   min-width: 45px;
#   display: -webkit-box;
#   display: flex;
#   -webkit-box-align: center;
#           align-items: center;
#   -webkit-box-pack: center;
#           justify-content: center;
#   cursor: pointer;
#   margin: 0 5px;
#   text-decoration: none;
#   padding: 0px 5px;
# }
# .pagination[_ngcontent-sc69]   .page-button.active[_ngcontent-sc69] {
#   background: #5f91bf;
#   color: #fff;
# ...
#                     <!-- -->
#                     <p _ngcontent-sc39="" class="app-tooltip">
#                      <!-- -->
#                      <!-- -->
#                      Grundstørrelse
#                      <!-- -->
#                      <!-- -->
#                     </p>
#                     <div _ngcontent-sc56="" class="d-flex flex-wrap pr-1">
#                      <svg _ngcontent-sc56="" class="icon-2 text-secondary">
#                       <use _ngcontent-sc56="" xlink:href="#icon-lot-size">
#                       </use>
#                      </svg>
#                      <span _ngcontent-sc56="" class="text-nowrap">
#                       0 m²
#                      </span>
#                     </div>
#                    </app-tooltip>
#                   </div>
#                   <div _ngcontent-sc56="" class="detail d-lg-flex">
#                    <app-tooltip _ngcontent-sc56="" _nghost-sc39="" class="tooltip-nowrap tooltip-top-left w-100">
#                     <!-- -->
#                     <p _ngcontent-sc39="" class="app-tooltip">
#                      <!-- -->
#                      <!-- -->
#                      Ejerudgift - de samlede månedlige udgifter til boligen uden lån
#                      <!-- -->
#                      <!-- -->
#                     </p>
#                     <div _ngcontent-sc56="" class="d-flex flex-wrap pr-1">
#                      <svg _ngcontent-sc56="" class="icon-2 text-secondary">
#                       <use _ngcontent-sc56="" xlink:href="#icon-taxes">
#                       </use>
#                      </svg>
#                      <span _ngcontent-sc56="" class="text-nowrap">
#                       Ejerudgift: 2.892  kr. / md.
#                      </span>
#                     </div>
#                    </app-tooltip>
#                   </div>
#                  </div>
#                 </app-house-details>
#                 <!-- -->
#                </div>
#               </div>
#               <!-- -->
#              </div>
#             </div>
#            </app-listing-information-lg>
#            <!-- -->
#           </a>
#          </app-housing-list-item>
#          <!-- -->
#          <!-- -->
#         </div>
#         <!-- -->
#         <app-pagination _ngcontent-sc61="" _nghost-sc69="">
#          <!-- -->
#          <div _ngcontent-sc69="" class="pagination">
#           <div _ngcontent-sc69="" class="nav-left">
#            <!-- -->
#            <!-- -->
#            <a _ngcontent-sc69="" class="page-button disabled prev">
#             Tilbage
#            </a>
#            <!-- -->
#           </div>
#           <div _ngcontent-sc69="" class="pages d-none d-md-flex">
#            <!-- -->
#            <a _ngcontent-sc69="" class="page-button active">
#             1
#            </a>
#            <a _ngcontent-sc69="" class="page-button">
#             2
#            </a>
#            <a _ngcontent-sc69="" class="page-button">
#             3
#            </a>
#           </div>
#           <div _ngcontent-sc69="" class="paging-stats mobile">
#            1 - 50
#           </div>
#           <div _ngcontent-sc69="" class="nav-right">
#            <!-- -->
#            <!-- -->
#            <!-- -->
#            <a _ngcontent-sc69="" class="page-button next">
#             Næste
#            </a>
#           </div>
#          </div>
#          <!-- -->
#          <div _ngcontent-sc69="" class="paging-stats">
#           1 - 50 af 103 resultater
#          </div>
#         </app-pagination>
#         <!-- -->
#        </div>
#        <!-- -->
#        <!-- -->
#       </app-housing-list-results>
#      </div>
#      <!-- -->
#     </app-housing-list>
#     <app-footer _ngcontent-sc0="" _nghost-sc3="" class="d-print-none">
#      <footer _ngcontent-sc3="" class="footer">
#       <div _ngcontent-sc3="" class="container">
#        <div _ngcontent-sc3="" class="row">
#         <div _ngcontent-sc3="" class="main">
#          <!-- -->
#          <app-footer-list _ngcontent-sc3="" _nghost-sc11="" class="col-12 col-md-3">
#           <div _ngcontent-sc11="" class="title title--top">
#           </div>
#           <ul _ngcontent-sc11="" class="list closed">
#            <!-- -->
#            <li _ngcontent-sc11="">
#             <!-- -->
#             <!-- -->
#             <a _ngcontent-sc11="" class="link" href="/vilkaar-og-betingelser">
#              Vilkår og betingelser
#             </a>
#            </li>
#            <li _ngcontent-sc11="">
#             <!-- -->
#             <!-- -->
#             <a _ngcontent-sc11="" class="link" href="/klagemulighed">
#              Klagemulighed
#             </a>
#            </li>
#            <li _ngcontent-sc11="">
#             <!-- -->
#             <!-- -->
#             <a _ngcontent-sc11="" class="link" href="/privatlivspolitik">
#              Cookie- og privatlivspolitik
#             </a>
#            </li>
#            <li _ngcontent-sc11="">
#             <!-- -->
#             <!-- -->
#             <a _ngcontent-sc11="" class="link" href="/persondatapolitik">
#              Persondatapolitik
#             </a>
#            </li>
#            <li _ngcontent-sc11="">
#             <!-- -->
#             <!-- -->
#             <a _ngcontent-sc11="" class="link" href="/faq">
#              FAQ
#             </a>
#            </li>
#            <li _ngcontent-sc11="">
#             <!-- -->
#             <!-- -->
#             <a _ngcontent-sc11="" class="link" href="/medarbejdere">
#              Medarbejdere
#             </a>
#            </li>
#            <li _ngcontent-sc11="">
#             <!-- -->
#             <a _ngcontent-sc11="" class="link" href="https://boligagruppen.dk/ledige-stillinger/" target="_blank">
#              Job
#             </a>
#             <!-- -->
#            </li>
#            <li _ngcontent-sc11="">
#             <!-- -->
#             <a _ngcontent-sc11="" class="link" href="https://boligagruppen.dk/" target="_blank">
#              Om virksomheden
#             </a>
#             <!-- -->
#            </li>
#           </ul>
#           <!-- -->
#          </app-footer-list>
#          <app-footer-list _ngcontent-sc3="" _nghost-sc11="" class="col-12 col-md-3">
#           <div _ngcontent-sc11="" class="title">
#           </div>
#           <ul _ngcontent-sc11="" class="list closed">
#            <!-- -->
#            <li _ngcontent-sc11="">
#             <!-- -->
#             <!-- -->
#             <a _ngcontent-sc11="" class="link" href="/artikler">
#              Nyhedsbrevet Bolignyt
#             </a>
#            </li>
#            <li _ngcontent-sc11="">
#             <!-- -->
#             <a _ngcontent-sc11="" class="link" href="https://itunes.apple.com/dk/app/boliga/id324901598?mt=8" target="_blank">
#              iPhone-app
#             </a>
#             <!-- -->
#            </li>
#            <li _ngcontent-sc11="">
#             <!-- -->
#             <a _ngcontent-sc11="" class="link" href="https://play.google.com/store/apps/details?id=com.boliga.boliga" target="_blank">
#              Android-app
#             </a>
#             <!-- -->
#            </li>
#           </ul>
#           <!-- -->
#          </app-footer-list>
#          <app-footer-list _ngcontent-sc3="" _nghost-sc11="" class="col-12 col-md-3">
#           <div _ngcontent-sc11="" class="title">
#           </div>
#           <ul _ngcontent-sc11="" class="list closed">
#            <!-- -->
#            <li _ngcontent-sc11="">
#             <!-- -->
#             <a _ngcontent-sc11="" class="link" href="https://www.selvsalg.dk/?utm_source=boliga&amp;utm_medium=footer&amp;utm_campaign=boliga-henvisning" target="_blank">
#              Boliga Selvsalg
#             </a>
#             <!-- -->
#            </li>
#            <li _ngcontent-sc11="">
#             <!-- -->
#             <a _ngcontent-sc11="" class="link" href="https://tilstandsrapport.dk/?utm_source=boliga&amp;utm_medium=footer&amp;utm_campaign=boliga-henvisning" target="_blank">
#              Tilstandsrapport.dk
#             </a>
#             <!-- -->
#            </li>
#            <li _ngcontent-sc11="">
#             <!-- -->
#             <a _ngcontent-sc11="" class="link" href="http://www.boligdebatten.dk/" target="_blank">
#              Boligdebatten.dk
#             </a>
#             <!-- -->
#            </li>
#            <li _ngcontent-sc11="">
#             <!-- -->
#             <a _ngcontent-sc11="" class="link" href="https://www.itvang.dk/?utm_source=boliga&amp;utm_medium=footer&amp;utm_campaign=boliga-henvisning" target="_blank">
#              ITvang.dk
#             </a>
#             <!-- -->
#            </li>
#            <li _ngcontent-sc11="">
#             <!-- -->
#             <a _ngcontent-sc11="" class="link" href="https://www.semithus.dk/?utm_source=boliga&amp;utm_medium=footer&amp;utm_campaign=boliga-henvisning" target="_blank">
#              SeMitHus.dk
#             </a>
#             <!-- -->
#            </li>
#            <li _ngcontent-sc11="">
#             <!-- -->
#             <!-- -->
#             <a _ngcontent-sc11="" class="link" data-gtm="footer_deed" href="/skoede">
#              Boliga Skøde
#             </a>
#            </li>
#           </ul>
#           <!-- -->
#          </app-footer-list>
#          <app-footer-list _ngcontent-sc3="" _nghost-sc11="" class="col-12 col-md-3">
#           <div _ngcontent-sc11="" class="title">
#           </div>
#           <ul _ngcontent-sc11="" class="list closed">
#            <!-- -->
#            <li _ngcontent-sc11="">
#             <!-- -->
#             <!-- -->
#             <a _ngcontent-sc11="" class="link" href="/boligdata">
#              Køb af boligdata
#             </a>
#            </li>
#            <li _ngcontent-sc11="">
#             <!-- -->
#             <a _ngcontent-sc11="" class="link" href="mailto:martin@boliga.com?subject=Forespørgsel til salgsafdelingen" target="_blank">
#              Salgsafdelingen
#             </a>
#             <!-- -->
#            </li>
#            <li _ngcontent-sc11="">
#             <!-- -->
#             <!-- -->
#             <a _ngcontent-sc11="" class="link" href="/kontakt">
#              Kontaktinformation
#             </a>
#            </li>
#            <li _ngcontent-sc11="">
#             <!-- -->
#             <!-- -->
#             <a _ngcontent-sc11="" class="link" href="/presse">
#              Presse
#             </a>
#            </li>
#           </ul>
#           <!-- -->
#           <ul _ngcontent-sc11="" class="col-2 col-md-3">
#            <div _ngcontent-sc11="" class="media">
#             <li _ngcontent-sc11="">
#              <a _ngcontent-sc11="" href="https://www.facebook.com/boliga">
#               <svg _ngcontent-sc11="" class="icon-1">
#                <use _ngcontent-sc11="" xlink:href="#icon-facebook">
#                </use>
#               </svg>
#              </a>
#             </li>
#             <li _ngcontent-sc11="">
#              <a _ngcontent-sc11="" href="https://www.twitter.com/Boliga">
#               <svg _ngcontent-sc11="" class="icon-1">
#                <use _ngcontent-sc11="" xlink:href="#icon-twitter">
#                </use>
#               </svg>
#              </a>
#             </li>
#            </div>
#           </ul>
#          </app-footer-list>
#         </div>
#        </div>
#       </div>
#       <div _ngcontent-sc3="" class="copyright">
#        <div _ngcontent-sc3="" class="container">
#         <div _ngcontent-sc3="" class="row">
#          <span _ngcontent-sc3="" class="col-12">
#           © 2020 Boliga ApS
#          </span>
#         </div>
#        </div>
#       </div>
#      </footer>
#     </app-footer>
#    </app-scroll-position-restoration>
#   </app-root>
#   <script defer="" src="runtime.b31d3f3642127e1c2143.js">
#   </script>
#   <script defer="" nomodule="" src="polyfills-es5.c3ef5be2f545307ab7df.js">
#   </script>
#   <script defer="" src="polyfills.91735be544ae5c0afd77.js">
#   </script>
#   <script defer="" src="main.8c3f8d14538388cc2a69.js">
#   </script>
#   <div aria-hidden="true" id="cdk-describedby-message-container" style="display: none;">
#    <div id="cdk-describedby-message-197544">
#     Gem bolig
#    </div>
#    <div id="cdk-describedby-message-197545">
#     Skjul bolig
#    </div>
#    <div id="cdk-describedby-message-197546">
#     Pris er faldet
#    </div>
#    <div id="cdk-describedby-message-197547">
#     Pris er steget
#    </div>
#   </div>
#   <script id="boliga-app-state" type="application/json">
#    {&q;transfer-translate-da&q;:{&q;agency_inner&q;:{&q;address&q;:&q;Adresse&q;,&q;all_for_sale&q;:&q;Alle boliger og grunde til salg&q;,&q;contact_agent&q;:&q;Kontakt mægleren og få en vurdering af din bolig&q;,&q;current_offers&q;:&q;Nuværende udbud&q;,&q;date&q;:&q;Oprettet&q;,&q;doesnt_show_pictures&q;:&q;Viser ikke billeder&q;,&q;go_to_website&q;:&q;Gå til mæglers hjemmeside&q;,&q;history&q;:&q;Tidligere til salg&q;,&q;history_of_property_sales&q;:&q;Historisk fordeling af boligtyper til salg&q;,&q;latest_properties_for_sale&q;:&q;Nyeste boliger og grunde til salg&q;,&q;price&q;:&q;Pris&q;,&q;property_history&q;:{&q;all_postal_codes&q;:&q;Alle postnumre&q;,&q;avg_number&q;:&q;Gennemsnitligt antal&q;,&q;length_of_stay&q;:&q;Liggetid&q;,&q;period&q;:&q;Periode&q;,&q;price_adjustment&q;:&q;Prisjustering&q;,&q;property_type&q;:&q;Boligtype&q;,&q;sqmPrice&q;:&q;Kr. / m²&q;,&q;table_description&q;:&q;Nedenstående er gennemsnitlige tal for alle de boliger og grunde, der har været til salg gennem  {{ agencyName }} de seneste seks måneder.&q;},&q;shows_pictures&q;:&q;Viser billeder&q;,&q;sold&q;:{&q;address&q;:&q;Adresse&q;,&q;area&q;:&q;m²&q;,&q;build&q;:&q;Byggeår&q;,&q;change&q;:&q;Prisjustering&q;,&q;meter_squered&q;:&q;m²&q;,&q;on_market&q;:&q;Liggetid&q;,&q;picture&q;:&q;Billede&q;,&q;plot&q;:&q;Grundstørrelse&q;,&q;postal&q;:&q;Postnummer&q;,&q;price&q;:&q;Købesum&q;,&q;properties_sold&q;:&q;{{ value }} boliger solgt&q;,&q;rooms&q;:&q;Værelser&q;,&q;sold_date&q;:&q;Salgsdato&q;,&q;sqmPrice&q;:&q;Kr. / m²&q;,&q;type&q;:&q;Boligtype&q;,&q;value&q;:&q;Aktuel værdi&q;},&q;sold_in_6_months&q;:&q;Solgt seneste 6 mdr.&q;,&q;types_for_sale&q;:&q;Fordeling af boligtyper til salg d.d.&q;,&q;view_more&q;:&q;Se mere&q;,&q;zip_code&q;:&q;Postnummer&q;},&q;articles&q;:{&q;all&q;:&q;Alle artikler&q;,&q;hints&q;:&q;Mest læste artikler&q;,&q;more_articles&q;:&q;Læs flere artikler fra Bolignyt&q;,&q;most_popular&q;:&q;Jurahjørnet&q;,&q;news&q;:&q;Bolignyt&q;,&q;no_articles_found&q;:&q;Vi kunne desværre ikke finde noget, der matchede din søgning - prøv igen!&q;,&q;search&q;:&q;Søg&q;},&q;auth&q;:{&q;account_created&q;:&q;Din brugerkonto er oprettet.&q;,&q;already_have_account&q;:&q;Har du allerede en bruger?&q;,&q;change&q;:{&q;change&q;:&q;Ændr kodeord&q;,&q;change_password&q;:&q;Skift kodeord!&q;,&q;changed&q;:&q;Kodeord er ændret!&q;,&q;new_password&q;:&q;Nyt kodeord&q;,&q;repeat_new_password&q;:&q;Gentag dit nye kodeord&q;,&q;validation_all_required&q;:&q;Alle felter skal udfyldes&q;,&q;validation_match&q;:&q;Kodeordene er ikke ens&q;},&q;choose_profile&q;:&q;Vælg profil&q;,&q;continue&q;:&q;Fortsæt&q;,&q;dont_have_an_account&q;:&q;Har du ikke en bruger endnu?&q;,&q;enter&q;:&q;Enter&q;,&q;errors&q;:{&q;fb_login_failed&q;:&q;Login med Facebook fejlede&q;,&q;invalid_grant&q;:&q;Fejl i brugernavn eller kodeord!&q;,&q;required_accept_terms&q;:&q;Du skal acceptere vores vilkår og betingelser for at oprette din bruger&q;,&q;validation_email&q;:&q;E-mailadressen skal indeholde et @&q;,&q;validation_required&q;:&q;{{ field_name }} er nødvendigt&q;},&q;fb_login&q;:&q;Login med Facebook&q;,&q;fields&q;:{&q;email&q;:&q;Indtast din e-mailadresse&q;,&q;newsletter&q;:&q;Ja, jeg vil gerne modtage Boligas nyhedsbreve og anden markedsføring. Jeg har læst og forstået&q;,&q;password&q;:&q;Kodeord&q;,&q;profile&q;:&q;Profil&q;,&q;remember&q;:&q;Husk mig&q;,&q;terms&q;:&q;Jeg har læst og accepteret Boliga ApS&s;s&q;,&q;username&q;:&q;E-mailadresse&q;,&q;zipcode&q;:&q;Postnummer&q;},&q;forgot_password&q;:&q;Glemt adgangskode?&q;,&q;heading&q;:&q;Log ind&q;,&q;profiles&q;:{&q;both&q;:&q;Både køber og sælger&q;,&q;buyer&q;:&q;Køber&q;,&q;neither&q;:&q;Hverken køber eller sælger&q;,&q;no_answer&q;:&q;Ønsker ikke at svare&q;,&q;seller&q;:&q;Sælger&q;},&q;registration_completed&q;:&q;Brugeroprettelse færdig!&q;,&q;remember_me&q;:&q;Husk mig&q;,&q;reset&q;:{&q;enter_email&q;:&q;Skriv din e-mailadresse&q;,&q;instructions&q;:&q;Vi har sendt dig en e-mail med flere o ...
#   </script>
#  </body>
# </html>

# %% [markdown]
# ## 1.2 Scraping

# %% [markdown]
# *Scraping* means to parse HTML and collect the important pieces of information inside. *Crawling* is
# another important contect, and the word refers to automatically sifting through pages of the web and scraping
# information on each page. 90% of scraping and crawling work can be done using the two modules `requests` and
# `BeautifulSoup`.

# %% [markdown]
# > **Ex. 4:** Load the toy example HTML with BeautifulSoup. Use the [documentation page](https://www.crummy.com/software/BeautifulSoup/bs4/doc/) for reference on how to do this.
# 1. Access the `h1` element inside the `div` and print out its content (which is "This is the main title of the webpage").
# 2. Get the value of the `src` attribute inside the `img` element.
# 3. Get the second subheading that contains "This is another sub-heading" and print out that content.
# 4. Get the `div` element by searching for its id.

# %%
#with open("exc5.2.example.html") as fp:
    #soup = BeautifulSoup(fp, "html.parser")

# %%
html_doc = """<html>
<body>

<div width=200 height=100 id="main">
    <h1>This is the main title of the webpage</h1>
    <h2>This is a sub-heading</h2>
    <p>This is a paragraph of text.</p>
</div>

<h2>This is another sub-heading</h2>
<p>This is a paragraph of text with some words in bold.</p>
<img src="https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Fmedia.giphy.com%2Fmedia%2FkFgzrTt798d2w%2Fgiphy.gif&f=1&nofb=1" width="493" height="340">
<p>And that just above is an image.</p>

</body>
</html>
"""

soup = BeautifulSoup(html_doc, 'html.parser')

# %%
soup
# Out:
# <html>
# <body>
# <div height="100" id="main" width="200">
# <h1>This is the main title of the webpage</h1>
# <h2>This is a sub-heading</h2>
# <p>This is a paragraph of text.</p>
# </div>
# <h2>This is another sub-heading</h2>
# <p>This is a paragraph of text with some words in bold.</p>
# <img height="340" src="https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Fmedia.giphy.com%2Fmedia%2FkFgzrTt798d2w%2Fgiphy.gif&amp;f=1&amp;nofb=1" width="493"/>
# <p>And that just above is an image.</p>
# </body>
# </html>

# %%
soup.h1.text
# Out:
# 'This is the main title of the webpage'

# %%
soup.img['src']
# Out:
# 'https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Fmedia.giphy.com%2Fmedia%2FkFgzrTt798d2w%2Fgiphy.gif&f=1&nofb=1'

# %% [markdown]
# > **Ex. 5** Load the HTML you downloaded in Ex. 3. For each post, extract price, square meter size and "Ejerudgift". You should create three different lists that contain each variable across posts.

# %% [markdown]
# > **Ex. 6:** Make a scatter plot of square meter size vs. extracted price. Then make a new variable that
# measures price per square meter and scatter plot this against "Ejerudgift". Can you say anything about how
# "Ejerudgift" influences square meter price?

# %% [markdown]
# > **Supercharge:** Crawl over pages of Boliga to collect this data for the entire borough of Nørrebro. Or all of Copenhagen!
